# %%
import csv
import string as st
        
def publict():
    filename="ai.csv"
    feids=[]
    rows=[]
    with open(filename, 'r') as csvfile: 
    # creating a csv reader object 
        csvreader = csv.reader(csvfile) 
 # extracting field names through first row 
        fields = next(csvreader) 
  
    # extracting each data row one by one 
        for row in csvreader: 
            rows.append(row) 
  

    print("\nWhich type of public transport are u looking for?\nEnter a keyword to help us find it for you:\n")
    keyword=input()
    print("\n\n")
    i=1
    for row in rows:
        for field in row:
            temp=field
            n=temp.find(keyword)
            if(n>-1) :
                i=i+1
                for x in row:
                    print(x)
                print('\n')
    if(i==1):
        print("\nTry to search with another keyword\n")
        publict()
def main():
    print("Welcome to section of vehicles for public transport\n")
    publict()
main()
# Out:
# Welcome to section of vehicles for public transport
#
#
# Which type of public transport are u looking for?
# Enter a keyword to help us find it for you:
#
# durable
#
#
#
# Car
# Vitara Brezza
# Personal,Public
# 21,32,45,57,68
# Suv
# Diesel
# 12
# durable,economical
#
#
# Truck
# Tata Ace
# Personal,Public
# 25,28,31,36
# Half Body
# Petrol,Diesel
# 4.36
# High milege,cheap,low maintainence,durable,economical
#
#
# Truck
# Tata Ace
# Personal,Public
# 25,28,31,36
# Half Body
# Diesel
# 4.2
# High milege,cheap,low maintainence,durable,economical
#
#
# Auto
# Mahindra Alfa
# Personal,Public
# 21,32,45,57,68
# Standard
# CNG,Petrol
# 1.52
# High milege,cheap,low maintainence,durable,economical
#
#
# Truck
# Tata
# Personal,Public
# 25,28,31,36
# Full Body
# Diesel
# 13.9
# High milege,cheap,low maintainence,durable,economical
#
#
# Auto
# Mahindra Alfa
# Personal,Public
# 25,28,31,36
# Standard
# CNG,Petrol
# 1.52
# High milege,cheap,low maintainence,durable,economical
#
#
# Auto
# Piaggio Ape
# Personal,Public
# 25,28,31,36
# Standard
# CNG,Petrol
# 1.75
# High milege,cheap,low maintainence,durable,economical
#
#
# Car
# Mercedes_Benz_A_160_Classic_Klima
# Public
# 21,32,45,57,68
# bus
# Benzin,Petrol
# 66
# durable,economical
#
#
# Auto
# Piaggio Ape
# Personal,Public
# 25,28,31,36
# Standard
# LPG,Petrol
# 1.8
# High milege,cheap,low maintainence,durable,economical
#
#
# Car
# Fiat_Punto_12
# Personal,Public
# 21,32,45,57,68
# kleinwagen
# Benzin,Petrol
# 16
# durable,economical
#
#
# Auto
# Bajaj RE
# Personal,Public
# 21,32,45,57,68
# Standard
# CNG,Petrol
# 2
# High milege,cheap,low maintainence,durable,economical
#
#
# Auto
# Bajaj RE
# Personal,Public
# 25,28,31,36
# Standard
# LPG,Petrol
# 1.87
# durable,economical
#
#
# Car
# Renault_Kangoo_19_Diesel
# Public
# 25,28,31,36
# Bus
# Diesel
# 9
# durable,economical
#
#
# Auto
# Bajaj RE
# Personal,Public
# 25,28,31,36
# Standard
# LPG,Petrol
# 2
# High milege,cheap,low maintainence,durable,economical
#
#
# Auto
# Bajaj RE
# Personal,Public
# 25,28,31,36
# Standard
# CNG,Petrol
# 1.75
# High milege,cheap,low maintainence,durable,economical
#
#
# Auto
# Atul Gemini
# Personal,Public
# 25,28,31,36
# Standard
# LPG,Petrol
# 1.75
# High milege,cheap,low maintainence,durable,economical
#
#
# Car
# Honda_HRV_reserviert
# Personal,Public
# 30,32,34
# Suv
# Benzin,Petrol
# 7
# High milege,cheap,low maintainence,durable,economical
#
#
# Auto
# Atul Gemini
# Personal,Public
# 25,28,31,36
# Standard
# LPG,Petrol
# 2.15
# High milege,cheap,low maintainence,durable,economical
#
#
# Auto
# Atul GEM
# Personal,Public
# 25,28,31,36
# Standard
# CNG,Petrol
# 2.07
# High milege,cheap,low maintainence,durable,economical
#
#
# Auto
# Atul
# Personal,Public
# 25,28,31,36
# Standard
# CNG,Petrol
# 2.19
# High milege,cheap,low maintainence,durable,economical
#
#
# Loader
# ACE
# Personal,Public
# 21,32,45,57,68
# Medium wheel
# Diesel
# 22
#  Cheap, durable, Low maintainance
#
#
# Truck
# Ashok Leyland
# Personal,Public
# 25,28,31,36
# Box body
# Diesel
# 18.2
# durable,economical
#
#
# Auto
# TukTuk
# Personal,Public
# 21,32,45,57,68
# Standard
# LPG,Petrol
# 2.03
# High milege,cheap,low maintainence,durable,economical
#
#
# Auto
# Alfa
# Personal,Public
# 21,32,45,57,68
# Standard
# Electric
# 1.2
# High milege,cheap,low maintainence,durable,economical
#
#
# Loader
# Volvo
# Personal,Public
# 25,28,31,36
# Medium wheel
# Diesel
# 35
#  Cheap, durable, Low maintainance
#
#
# Auto
# TukTuk
# Personal,Public
# 25,28,31,36
# Standard
# CNG,Petrol
# 2.2
# High milege,cheap,low maintainence,durable,economical
#
#
# Auto
# TukTuk
# Personal-Public
# 25-28-31-36
# Standard
# CNG-Petrol
# 2.05
# High milege-cheap-low maintainence-durable-economical
#
#
# Auto
# TukTuk
# Personal-Public
# 25-28-31-36
# Standard
# CNG-Petrol
# 2.15
# High milege-cheap-low maintainence-durable-economical
#
#
# Car
# Volkswagen_Touran_19_TDI_DPF_Navi_PDC_Tempomat_AHK_TUV_Neu
# Public
# 25-28-31-36
# Bus
# Diesel
# 14
# High milege-cheap-low maintainence-durable-economical
#
#
# Loader
# Monitau
# Personal-Public
# 30-32-34
# Compact Wheel
# Diesel
# 46
#  Cheap- durable- Low maintainance
#
#
# Auto
# Baxy
# Personal-Public
# 25-28-31-36
# Standard
# LPG-Petrol
# 2.3
# High milege-cheap-low maintainence-durable-economical
#
#
# Auto
# Hero
# Personal-Public
# 21-32-45-57-68
# Compact
# Electrical
# 1.1
# High milege-cheap-low maintainence-durable-economical
